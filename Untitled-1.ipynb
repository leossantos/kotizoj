# %%
#retrieve stock data
import pandas as pd
import yfinance as yf
import numpy as np

def get_stock_price(ticker):
    stock = yf.Ticker(f"{ticker}.SA")
    return stock.fast_info['lastPrice']

def get_stock_data(ticker):
    stock = yf.Ticker(f"{ticker}.SA")
    return stock

def input_stock_price(wallet):
    for stock in wallet:
        if stock['Ativo'] == 'Tesouro Selic':
            continue
        print(stock['Ativo'])
        stock_price = get_stock_price(stock['Ativo'])
        stock['Preço'] = round(stock_price, 2)

# %%
aporte = 448
wallet = [{'Ativo': 'BBAS3',
  'Prioridade': 2,
  'Quantidade Atual': 4,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'BTLG11',
  'Prioridade': 1,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'VGIP11',
  'Prioridade': 5,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'BLAU3',
  'Prioridade': 3,
  'Quantidade Atual': 11,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'EGIE3',
  'Prioridade': 4,
  'Quantidade Atual': 5,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'PVBI11',
  'Prioridade': 7,
  'Quantidade Atual': 1,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'MALL11',
  'Prioridade': 6,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'HGRU11',
  'Prioridade': 9,
  'Quantidade Atual': 1,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'AGRO3',
  'Prioridade': 8,
  'Quantidade Atual': 7,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'IVVB11',
  'Prioridade': 10,
  'Quantidade Atual': 1,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'B5P211',
  'Prioridade': 11,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'RBRP11',
  'Prioridade': 12,
  'Quantidade Atual': 3,
  'Balanceamento': 0.075,
  'Comprar': True},
  {'Ativo': 'Tesouro Selic',
  'Prioridade': 13,
  'Quantidade Atual': 0.02,
  'Balanceamento': 0.1,
  'Preço': 13715.26,
  'Comprar': True}
]

# %%
input_stock_price(wallet)
# Out:
# BBAS3
# BTLG11
# VGIP11
# BLAU3
# EGIE3
# PVBI11
# MALL11
# HGRU11
# AGRO3
# IVVB11
# B5P211
# RBRP11

# %%
aporte
# Out:
# 448

# %%
#explique o código abaixo

df = pd.DataFrame(wallet)
df['Posição'] = df['Preço']*df['Quantidade Atual']
df['Balanceamento Atual'] = df['Posição']/df['Posição'].sum()
atual = df['Posição'].sum()
fator_ajuste = 1/df[df['Comprar'] == True]['Balanceamento'].sum()
sum_sem_aporte = df[df['Comprar']== False]['Balanceamento'].sum()
df['Posição Ideal'] = np.where(
    (df['Comprar']==True) & (df['Balanceamento']*(aporte+atual) > df['Posição']),
    df['Balanceamento']*(aporte+atual),
    df['Posição']
)

df['Aporte Ideal'] = np.where(
    df['Posição Ideal'] > df['Posição'], df['Posição Ideal'] - df['Posição'], 0
) 
sum_sem_aporte = df[df['Comprar']== False]['Balanceamento'].sum()

fator_ajuste = 1/df[df['Aporte Ideal'] > 0]['Balanceamento'].sum()


sum_sobra = (aporte+atual)- df['Posição Ideal'].sum()
df['Posição Ideal'] = np.where(
    df['Aporte Ideal'] > 0,
    df['Posição Ideal'] + df['Balanceamento']*fator_ajuste*sum_sobra,
    df['Posição']
)

df['Aporte Ideal'] = df['Posição Ideal'] - df['Posição']
df['Quantidade Aporte'] = np.where(
    df['Ativo'] != 'Tesouro Selic',
    np.trunc(df['Aporte Ideal']/df['Preço']),
    np.trunc(df['Aporte Ideal']/df['Preço']*100)/100
)

df['Aporte Real'] = df['Quantidade Aporte']*df['Preço']
df['Posição após aporte real'] = df['Posição'] + df['Aporte Real']
df['Balanceamento após aporte real'] = df['Posição após aporte real']/df['Posição após aporte real'].sum()
df['Diferença Balanceamento'] = df['Balanceamento após aporte real'] - df['Balanceamento']
restante_aporte = aporte - df['Aporte Real'].sum()

wallet = df.to_dict('records')

# %%
wallet
# Out:
# [{'Ativo': 'BBAS3',
#   'Prioridade': 2,
#   'Quantidade Atual': 4.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 49.36,
#   'Posição': 197.44,
#   'Balanceamento Atual': 0.07983808525756438,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 18.36457647058819,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 197.44,
#   'Balanceamento após aporte real': 0.07411563871509068,
#   'Diferença Balanceamento': -0.0008843612849093185},
#  {'Ativo': 'BTLG11',
#   'Prioridade': 1,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 100.46,
#   'Posição': 200.92,
#   'Balanceamento Atual': 0.08124528003418675,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 14.8845764705882,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 200.92,
#   'Balanceamento após aporte real': 0.07542197189341582,
#   'Diferença Balanceamento': 0.00042197189341582064},
#  {'Ativo': 'VGIP11',
#   'Prioridade': 5,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 88.24,
#   'Posição': 176.48,
#   'Balanceamento Atual': 0.07136256729262033,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 39.3245764705882,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 176.48,
#   'Balanceamento após aporte real': 0.06624760899736225,
#   'Diferença Balanceamento': -0.00875239100263775},
#  {'Ativo': 'BLAU3',
#   'Prioridade': 3,
#   'Quantidade Atual': 11.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 16.21,
#   'Posição': 178.31,
#   'Balanceamento Atual': 0.07210255764929246,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 37.494576470588186,
#   'Quantidade Aporte': 2.0,
#   'Aporte Real': 32.42,
#   'Posição após aporte real': 210.73000000000002,
#   'Balanceamento após aporte real': 0.07910448007714273,
#   'Diferença Balanceamento': 0.00410448007714273},
#  {'Ativo': 'EGIE3',
#   'Prioridade': 4,
#   'Quantidade Atual': 5.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 41.07,
#   'Posição': 205.35,
#   'Balanceamento Atual': 0.08303662281017445,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 10.454576470588194,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 205.35,
#   'Balanceamento após aporte real': 0.07708491901409983,
#   'Diferença Balanceamento': 0.002084919014099837},
#  {'Ativo': 'PVBI11',
#   'Prioridade': 7,
#   'Quantidade Atual': 1.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 105.6,
#   'Posição': 105.6,
#   'Balanceamento Atual': 0.042701082876817245,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 110.2045764705882,
#   'Quantidade Aporte': 1.0,
#   'Aporte Real': 105.6,
#   'Posição após aporte real': 211.2,
#   'Balanceamento após aporte real': 0.07928091013283606,
#   'Diferença Balanceamento': 0.0042809101328360605},
#  {'Ativo': 'MALL11',
#   'Prioridade': 6,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 115.48,
#   'Posição': 230.96,
#   'Balanceamento Atual': 0.09339244414043288,
#   'Posição Ideal': 230.96,
#   'Aporte Ideal': 0.0,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 230.96,
#   'Balanceamento após aporte real': 0.08669848013390065,
#   'Diferença Balanceamento': 0.011698480133900652},
#  {'Ativo': 'HGRU11',
#   'Prioridade': 9,
#   'Quantidade Atual': 1.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 130.0,
#   'Posição': 130.0,
#   'Balanceamento Atual': 0.052567620965778813,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 85.80457647058819,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 130.0,
#   'Balanceamento após aporte real': 0.0487998026385828,
#   'Diferença Balanceamento': -0.026200197361417196},
#  {'Ativo': 'AGRO3',
#   'Prioridade': 8,
#   'Quantidade Atual': 7.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 29.06,
#   'Posição': 203.42,
#   'Balanceamento Atual': 0.08225619582199019,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 12.3845764705882,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 203.42,
#   'Balanceamento após aporte real': 0.07636042963646548,
#   'Diferença Balanceamento': 0.0013604296364654878},
#  {'Ativo': 'IVVB11',
#   'Prioridade': 10,
#   'Quantidade Atual': 1.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 244.26,
#   'Posição': 244.26,
#   'Balanceamento Atual': 0.09877051613154716,
#   'Posição Ideal': 244.26,
#   'Aporte Ideal': 0.0,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 244.26,
#   'Balanceamento após aporte real': 0.09169107532692489,
#   'Diferença Balanceamento': 0.01669107532692489},
#  {'Ativo': 'B5P211',
#   'Prioridade': 11,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 83.6,
#   'Posição': 167.2,
#   'Balanceamento Atual': 0.06761004788829397,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 48.6045764705882,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 167.2,
#   'Balanceamento após aporte real': 0.06276405385516187,
#   'Diferença Balanceamento': -0.012235946144838125},
#  {'Ativo': 'RBRP11',
#   'Prioridade': 12,
#   'Quantidade Atual': 3.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 52.92,
#   'Posição': 158.76,
#   'Balanceamento Atual': 0.06419719618866956,
#   'Posição Ideal': 215.8045764705882,
#   'Aporte Ideal': 57.0445764705882,
#   'Quantidade Aporte': 1.0,
#   'Aporte Real': 52.92,
#   'Posição após aporte real': 211.68,
#   'Balanceamento após aporte real': 0.0794610940195016,
#   'Diferença Balanceamento': 0.0044610940195016074},
#  {'Ativo': 'Tesouro Selic',
#   'Prioridade': 13,
#   'Quantidade Atual': 0.02,
#   'Balanceamento': 0.1,
#   'Comprar': True,
#   'Preço': 13715.26,
#   'Posição': 274.3052,
#   'Balanceamento Atual': 0.11091978294263193,
#   'Posição Ideal': 287.7394352941176,
#   'Aporte Ideal': 13.43423529411757,
#   'Quantidade Aporte': 0.0,
#   'Aporte Real': 0.0,
#   'Posição após aporte real': 274.3052,
#   'Balanceamento após aporte real': 0.10296953555951527,
#   'Diferença Balanceamento': 0.002969535559515263}]

# %%
from operator import itemgetter


restante_aporte = aporte - df['Aporte Real'].sum()
montante = df['Posição após aporte real'].sum()
wallet = sorted(wallet, key=itemgetter('Diferença Balanceamento'))
preco_minimo = df['Preço'].min()

i = 0
mark=''
while restante_aporte > preco_minimo:
    print('restante_aporte: ', restante_aporte)
    if i == len(wallet):
        i = 0
    ativo = wallet[i]
    if f'{ativo["Ativo"]}-{restante_aporte}' == mark:
        break
    print(ativo['Ativo'])
    ativo['Balanceamento após aporte real'] = ativo['Posição após aporte real']/montante
    if ativo['Comprar'] and ativo['Balanceamento após aporte real'] < ativo['Balanceamento']:
        if ativo['Ativo'] != 'Tesouro Selic' and restante_aporte > ativo['Preço']:
            mark = ''
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 1
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']
            montante += ativo['Preço']
            ativo['Balanceamento após aporte real'] = ativo['Posição após aporte real']/montante
        elif ativo['Ativo'] == 'Tesouro Selic' and restante_aporte > ativo['Preço']/100:
            mark = ''
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 0.01
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']/100
            montante += ativo['Preço']/100
            ativo['Balanceamento após aporte real'] = ativo['Posição após aporte real']/montante
    elif mark == '':
        mark = f'{ativo["Ativo"]}-{restante_aporte}'
    i+=1

print('Prioridade')
wallet = sorted(wallet, key=itemgetter('Prioridade'))
i=0
while restante_aporte > preco_minimo:
    print('restante_aporte: ', restante_aporte)
    if i == len(wallet):
        i = 0
    ativo = wallet[i]
    print(ativo['Ativo'])
    print('Preço: ', ativo['Preço'])
    if ativo['Comprar']:
        if ativo['Ativo'] != 'Tesouro Selic' and restante_aporte > ativo['Preço']:
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 1
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']
        elif ativo['Ativo'] == 'Tesouro Selic' and restante_aporte > ativo['Preço']/100:
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 0.01
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']/100
    i+=1
# Out:
# restante_aporte:  257.06
# HGRU11
# 0.0
# 0.0
# 1.0
# 130.0
# restante_aporte:  127.06
# B5P211
# 0.0
# 0.0
# 1.0
# 83.6
# restante_aporte:  43.46000000000001
# VGIP11
# restante_aporte:  43.46000000000001
# BBAS3
# restante_aporte:  43.46000000000001
# BTLG11
# restante_aporte:  43.46000000000001
# AGRO3
# 0.0
# 0.0
# 1.0
# 29.06
# Prioridade

# %%
df = pd.DataFrame(wallet)
df['Posição após aporte real'] = df['Posição'] + df['Aporte Real']
df['Balanceamento após aporte real'] = df['Posição após aporte real']/df['Posição após aporte real'].sum()

# %%
print(atual+aporte)
print(df['Aporte Ideal'].sum())
print(df['Posição Ideal'].sum())
print(df['Aporte Real'].sum())
print(restante_aporte)
df.sort_values('Prioridade')
# Out:
# 2921.0051999999996
# 447.9999999999995
# 2921.0051999999987
# 433.59999999999997
# 14.40000000000001
#             Ativo  Prioridade  Quantidade Atual  Balanceamento  Comprar  \
# 0          BTLG11           1              2.00          0.075     True
# 1           BBAS3           2              4.00          0.075     True
# 2           BLAU3           3             11.00          0.075     True
# 3           EGIE3           4              5.00          0.075     True
# 4          VGIP11           5              2.00          0.075     True
# 5          MALL11           6              2.00          0.075     True
# 6          PVBI11           7              1.00          0.075     True
# 7           AGRO3           8              7.00          0.075     True
# 8          HGRU11           9              1.00          0.075     True
# 9          IVVB11          10              1.00          0.075     True
# 10         B5P211          11              2.00          0.075     True
# 11         RBRP11          12              3.00          0.075     True
# 12  Tesouro Selic          13              0.02          0.100     True
#
#        Preço   Posição  Balanceamento Atual  Posição Ideal  Aporte Ideal  \
# 0     100.46  200.9200             0.081245     215.804576     14.884576
# 1      49.36  197.4400             0.079838     215.804576     18.364576
# 2      16.21  178.3100             0.072103     215.804576     37.494576
# 3      41.07  205.3500             0.083037     215.804576     10.454576
# 4      88.24  176.4800             0.071363     215.804576     39.324576
# 5     115.48  230.9600             0.093392     230.960000      0.000000
# 6     105.60  105.6000             0.042701     215.804576    110.204576
# 7      29.06  203.4200             0.082256     215.804576     12.384576
# 8     130.00  130.0000             0.052568     215.804576     85.804576
# 9     244.26  244.2600             0.098771     244.260000      0.000000
# 10     83.60  167.2000             0.067610     215.804576     48.604576
# 11     52.92  158.7600             0.064197     215.804576     57.044576
# 12  13715.26  274.3052             0.110920     287.739435     13.434235
#
#     Quantidade Aporte  Aporte Real  Posição após aporte real  \
# 0                 0.0         0.00                  200.9200
# 1                 0.0         0.00                  197.4400
# 2                 2.0        32.42                  210.7300
# 3                 0.0         0.00                  205.3500
# 4                 0.0         0.00                  176.4800
# 5                 0.0         0.00                  230.9600
# 6                 1.0       105.60                  211.2000
# 7                 1.0        29.06                  232.4800
# 8                 1.0       130.00                  260.0000
# 9                 0.0         0.00                  244.2600
# 10                1.0        83.60                  250.8000
# 11                1.0        52.92                  211.6800
# 12                0.0         0.00                  274.3052
#
#     Balanceamento após aporte real  Diferença Balanceamento
# 0                         0.069125                 0.000422
# 1                         0.067928                -0.000884
# 2                         0.072500                 0.004104
# 3                         0.070649                 0.002085
# 4                         0.060717                -0.008752
# 5                         0.079460                 0.011698
# 6                         0.072662                 0.004281
# 7                         0.079983                 0.001360
# 8                         0.089451                -0.026200
# 9                         0.084036                 0.016691
# 10                        0.086286                -0.012236
# 11                        0.072827                 0.004461
# 12                        0.094373                 0.002970

# %%
df['Quantidade Atual'] = df['Quantidade Atual'] + df['Quantidade Aporte']

# %%
df.sort_values('Prioridade')
# Out:
#             Ativo  Prioridade  Quantidade Atual  Balanceamento  Comprar  \
# 0          BTLG11           1              2.00          0.075     True
# 1           BBAS3           2              4.00          0.075     True
# 2           BLAU3           3             13.00          0.075     True
# 3           EGIE3           4              5.00          0.075     True
# 4          VGIP11           5              2.00          0.075     True
# 5          MALL11           6              2.00          0.075     True
# 6          PVBI11           7              2.00          0.075     True
# 7           AGRO3           8              8.00          0.075     True
# 8          HGRU11           9              2.00          0.075     True
# 9          IVVB11          10              1.00          0.075     True
# 10         B5P211          11              3.00          0.075     True
# 11         RBRP11          12              4.00          0.075     True
# 12  Tesouro Selic          13              0.02          0.100     True
#
#        Preço   Posição  Balanceamento Atual  Posição Ideal  Aporte Ideal  \
# 0     100.46  200.9200             0.081245     215.804576     14.884576
# 1      49.36  197.4400             0.079838     215.804576     18.364576
# 2      16.21  178.3100             0.072103     215.804576     37.494576
# 3      41.07  205.3500             0.083037     215.804576     10.454576
# 4      88.24  176.4800             0.071363     215.804576     39.324576
# 5     115.48  230.9600             0.093392     230.960000      0.000000
# 6     105.60  105.6000             0.042701     215.804576    110.204576
# 7      29.06  203.4200             0.082256     215.804576     12.384576
# 8     130.00  130.0000             0.052568     215.804576     85.804576
# 9     244.26  244.2600             0.098771     244.260000      0.000000
# 10     83.60  167.2000             0.067610     215.804576     48.604576
# 11     52.92  158.7600             0.064197     215.804576     57.044576
# 12  13715.26  274.3052             0.110920     287.739435     13.434235
#
#     Quantidade Aporte  Aporte Real  Posição após aporte real  \
# 0                 0.0         0.00                  200.9200
# 1                 0.0         0.00                  197.4400
# 2                 2.0        32.42                  210.7300
# 3                 0.0         0.00                  205.3500
# 4                 0.0         0.00                  176.4800
# 5                 0.0         0.00                  230.9600
# 6                 1.0       105.60                  211.2000
# 7                 1.0        29.06                  232.4800
# 8                 1.0       130.00                  260.0000
# 9                 0.0         0.00                  244.2600
# 10                1.0        83.60                  250.8000
# 11                1.0        52.92                  211.6800
# 12                0.0         0.00                  274.3052
#
#     Balanceamento após aporte real  Diferença Balanceamento
# 0                         0.069125                 0.000422
# 1                         0.067928                -0.000884
# 2                         0.072500                 0.004104
# 3                         0.070649                 0.002085
# 4                         0.060717                -0.008752
# 5                         0.079460                 0.011698
# 6                         0.072662                 0.004281
# 7                         0.079983                 0.001360
# 8                         0.089451                -0.026200
# 9                         0.084036                 0.016691
# 10                        0.086286                -0.012236
# 11                        0.072827                 0.004461
# 12                        0.094373                 0.002970
