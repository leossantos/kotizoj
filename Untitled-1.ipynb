# %%
#retrieve stock data
import pandas as pd
import yfinance as yf
import numpy as np

def get_stock_price(ticker):
    stock = yf.Ticker(f"{ticker}.SA")
    return stock.fast_info['lastPrice']

def get_stock_data(ticker):
    stock = yf.Ticker(f"{ticker}.SA")
    return stock

def input_stock_price(wallet):
    for stock in wallet:
        if stock['Ativo'] == 'Tesouro Selic':
            continue
        print(stock['Ativo'])
        stock_price = get_stock_price(stock['Ativo'])
        stock['Preço'] = round(stock_price, 2)

# %%
aporte = 5400
wallet = [{'Ativo': 'BBAS3',
  'Prioridade': 2,
  'Quantidade Atual': 4,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'BTLG11',
  'Prioridade': 1,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'VGIP11',
  'Prioridade': 5,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'BLAU3',
  'Prioridade': 3,
  'Quantidade Atual': 11,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'EGIE3',
  'Prioridade': 4,
  'Quantidade Atual': 5,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'PVBI11',
  'Prioridade': 7,
  'Quantidade Atual': 1,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'MALL11',
  'Prioridade': 6,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'HGRU11',
  'Prioridade': 9,
  'Quantidade Atual': 1,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'AGRO3',
  'Prioridade': 8,
  'Quantidade Atual': 7,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'IVVB11',
  'Prioridade': 10,
  'Quantidade Atual': 1,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'B5P211',
  'Prioridade': 11,
  'Quantidade Atual': 2,
  'Balanceamento': 0.075,
  'Comprar': True},
 {'Ativo': 'RBRP11',
  'Prioridade': 12,
  'Quantidade Atual': 3,
  'Balanceamento': 0.075,
  'Comprar': True},
  {'Ativo': 'Tesouro Selic',
  'Prioridade': 13,
  'Quantidade Atual': 0.02,
  'Balanceamento': 0.1,
  'Preço': 13715.26,
  'Comprar': True}
]

# %%
input_stock_price(wallet)
# Out:
# BBAS3
# BTLG11
# VGIP11
# BLAU3
# EGIE3
# PVBI11
# MALL11
# HGRU11
# AGRO3
# IVVB11
# B5P211
# RBRP11

# %%
aporte
# Out:
# 5400

# %%
#explique o código abaixo

df = pd.DataFrame(wallet)
df['Posição'] = df['Preço']*df['Quantidade Atual']
df['Balanceamento Atual'] = df['Posição']/df['Posição'].sum()
atual = df['Posição'].sum()
fator_ajuste = 1/df[df['Comprar'] == True]['Balanceamento'].sum()
sum_sem_aporte = df[df['Comprar']== False]['Balanceamento'].sum()
df['Posição Ideal'] = np.where(
    (df['Comprar']==True) & (df['Balanceamento']*(aporte+atual) > df['Posição']),
    df['Balanceamento']*(aporte+atual),
    df['Posição']
)

df['Aporte Ideal'] = np.where(
    df['Posição Ideal'] > df['Posição'], df['Posição Ideal'] - df['Posição'], 0
) 
sum_sem_aporte = df[df['Comprar']== False]['Balanceamento'].sum()

fator_ajuste = 1/df[df['Aporte Ideal'] > 0]['Balanceamento'].sum()


sum_sobra = (aporte+atual)- df['Posição Ideal'].sum()
df['Posição Ideal'] = np.where(
    df['Aporte Ideal'] > 0,
    df['Posição Ideal'] + df['Balanceamento']*fator_ajuste*sum_sobra,
    df['Posição']
)

df['Aporte Ideal'] = df['Posição Ideal'] - df['Posição']
df['Quantidade Aporte'] = np.where(
    df['Ativo'] != 'Tesouro Selic',
    np.trunc(df['Aporte Ideal']/df['Preço']),
    np.trunc(df['Aporte Ideal']/df['Preço']*100)/100
)

df['Aporte Real'] = df['Quantidade Aporte']*df['Preço']
df['Posição após aporte real'] = df['Posição'] + df['Aporte Real']
df['Balanceamento após aporte real'] = df['Posição após aporte real']/df['Posição após aporte real'].sum()
df['Diferença Balanceamento'] = df['Balanceamento após aporte real'] - df['Balanceamento']
restante_aporte = aporte - df['Aporte Real'].sum()

wallet = df.to_dict('records')

# %%
wallet
# Out:
# [{'Ativo': 'BBAS3',
#   'Prioridade': 2,
#   'Quantidade Atual': 4.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 47.7,
#   'Posição': 190.8,
#   'Balanceamento Atual': 0.07631862015934754,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 401.70339000000007,
#   'Quantidade Aporte': 8.0,
#   'Aporte Real': 381.6,
#   'Posição após aporte real': 572.4000000000001,
#   'Balanceamento após aporte real': 0.07791822751550709,
#   'Diferença Balanceamento': 0.002918227515507091},
#  {'Ativo': 'BTLG11',
#   'Prioridade': 1,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 101.88,
#   'Posição': 203.76,
#   'Balanceamento Atual': 0.08150252643432208,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 388.7433900000001,
#   'Quantidade Aporte': 3.0,
#   'Aporte Real': 305.64,
#   'Posição após aporte real': 509.4,
#   'Balanceamento após aporte real': 0.06934232197134749,
#   'Diferença Balanceamento': -0.00565767802865251},
#  {'Ativo': 'VGIP11',
#   'Prioridade': 5,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 89.22,
#   'Posição': 178.44,
#   'Balanceamento Atual': 0.07137470954525144,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 414.0633900000001,
#   'Quantidade Aporte': 4.0,
#   'Aporte Real': 356.88,
#   'Posição após aporte real': 535.3199999999999,
#   'Balanceamento após aporte real': 0.07287069453808744,
#   'Diferença Balanceamento': -0.0021293054619125618},
#  {'Ativo': 'BLAU3',
#   'Prioridade': 3,
#   'Quantidade Atual': 11.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 16.53,
#   'Posição': 181.83,
#   'Balanceamento Atual': 0.07273068502921469,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 410.67339000000004,
#   'Quantidade Aporte': 24.0,
#   'Aporte Real': 396.72,
#   'Posição após aporte real': 578.5500000000001,
#   'Balanceamento após aporte real': 0.07875539924719886,
#   'Diferença Balanceamento': 0.003755399247198865},
#  {'Ativo': 'EGIE3',
#   'Prioridade': 4,
#   'Quantidade Atual': 5.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 43.41,
#   'Posição': 217.04999999999998,
#   'Balanceamento Atual': 0.08681843032277978,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 375.4533900000001,
#   'Quantidade Aporte': 8.0,
#   'Aporte Real': 347.28,
#   'Posição após aporte real': 564.3299999999999,
#   'Balanceamento após aporte real': 0.07681969485294568,
#   'Diferença Balanceamento': 0.001819694852945683},
#  {'Ativo': 'PVBI11',
#   'Prioridade': 7,
#   'Quantidade Atual': 1.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 107.2,
#   'Posição': 107.2,
#   'Balanceamento Atual': 0.04287922474361664,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 485.3033900000001,
#   'Quantidade Aporte': 4.0,
#   'Aporte Real': 428.8,
#   'Posição após aporte real': 536.0,
#   'Balanceamento após aporte real': 0.07296325986777043,
#   'Diferença Balanceamento': -0.0020367401322295697},
#  {'Ativo': 'MALL11',
#   'Prioridade': 6,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 116.55,
#   'Posição': 233.1,
#   'Balanceamento Atual': 0.09323831425127835,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 359.40339000000006,
#   'Quantidade Aporte': 3.0,
#   'Aporte Real': 349.65,
#   'Posição após aporte real': 582.75,
#   'Balanceamento após aporte real': 0.07932712628347616,
#   'Diferença Balanceamento': 0.00432712628347616},
#  {'Ativo': 'HGRU11',
#   'Prioridade': 9,
#   'Quantidade Atual': 1.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 137.85,
#   'Posição': 137.85,
#   'Balanceamento Atual': 0.0551390030868242,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 454.65339000000006,
#   'Quantidade Aporte': 3.0,
#   'Aporte Real': 413.54999999999995,
#   'Posição após aporte real': 551.4,
#   'Balanceamento após aporte real': 0.07505959233412055,
#   'Diferença Balanceamento': 5.9592334120547874e-05},
#  {'Ativo': 'AGRO3',
#   'Prioridade': 8,
#   'Quantidade Atual': 7.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 28.14,
#   'Posição': 196.98000000000002,
#   'Balanceamento Atual': 0.07879057546639559,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 395.52339000000006,
#   'Quantidade Aporte': 14.0,
#   'Aporte Real': 393.96000000000004,
#   'Posição após aporte real': 590.94,
#   'Balanceamento após aporte real': 0.08044199400421691,
#   'Diferença Balanceamento': 0.00544199400421691},
#  {'Ativo': 'IVVB11',
#   'Prioridade': 10,
#   'Quantidade Atual': 1.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 238.33,
#   'Posição': 238.33,
#   'Balanceamento Atual': 0.09533027642860219,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 354.17339000000004,
#   'Quantidade Aporte': 1.0,
#   'Aporte Real': 238.33,
#   'Posição após aporte real': 476.66,
#   'Balanceamento após aporte real': 0.06488557359808107,
#   'Diferença Balanceamento': -0.010114426401918925},
#  {'Ativo': 'B5P211',
#   'Prioridade': 11,
#   'Quantidade Atual': 2.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 83.95,
#   'Posição': 167.9,
#   'Balanceamento Atual': 0.06715878576915331,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 424.6033900000001,
#   'Quantidade Aporte': 5.0,
#   'Aporte Real': 419.75,
#   'Posição após aporte real': 587.65,
#   'Balanceamento após aporte real': 0.079994141159133,
#   'Diferença Balanceamento': 0.004994141159133006},
#  {'Ativo': 'RBRP11',
#   'Prioridade': 12,
#   'Quantidade Atual': 3.0,
#   'Balanceamento': 0.075,
#   'Comprar': True,
#   'Preço': 57.5,
#   'Posição': 172.5,
#   'Balanceamento Atual': 0.06899875250255477,
#   'Posição Ideal': 592.5033900000001,
#   'Aporte Ideal': 420.0033900000001,
#   'Quantidade Aporte': 7.0,
#   'Aporte Real': 402.5,
#   'Posição após aporte real': 575.0,
#   'Balanceamento após aporte real': 0.0782721537760597,
#   'Diferença Balanceamento': 0.0032721537760597025},
#  {'Ativo': 'Tesouro Selic',
#   'Prioridade': 13,
#   'Quantidade Atual': 0.02,
#   'Balanceamento': 0.1,
#   'Comprar': True,
#   'Preço': 13715.26,
#   'Posição': 274.3052,
#   'Balanceamento Atual': 0.10972009626065964,
#   'Posição Ideal': 790.0045200000001,
#   'Aporte Ideal': 515.6993200000001,
#   'Quantidade Aporte': 0.03,
#   'Aporte Real': 411.45779999999996,
#   'Posição após aporte real': 685.7629999999999,
#   'Balanceamento após aporte real': 0.09334982085205569,
#   'Diferença Balanceamento': -0.006650179147944316}]

# %%
from operator import itemgetter


restante_aporte = aporte - df['Aporte Real'].sum()
montante = df['Posição após aporte real'].sum()
wallet = sorted(wallet, key=itemgetter('Diferença Balanceamento'))
preco_minimo = df['Preço'].min()

i = 0
mark=''
while restante_aporte > preco_minimo:
    print('restante_aporte: ', restante_aporte)
    if i == len(wallet):
        i = 0
    ativo = wallet[i]
    if f'{ativo["Ativo"]}-{restante_aporte}' == mark:
        break
    print(ativo['Ativo'])
    ativo['Balanceamento após aporte real'] = ativo['Posição após aporte real']/montante
    if ativo['Comprar'] and ativo['Balanceamento após aporte real'] < ativo['Balanceamento']:
        if ativo['Ativo'] != 'Tesouro Selic' and restante_aporte > ativo['Preço']:
            mark = ''
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 1
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']
            montante += ativo['Preço']
            ativo['Balanceamento após aporte real'] = ativo['Posição após aporte real']/montante
        elif ativo['Ativo'] == 'Tesouro Selic' and restante_aporte > ativo['Preço']/100:
            mark = ''
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 0.01
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']/100
            montante += ativo['Preço']/100
            ativo['Balanceamento após aporte real'] = ativo['Posição após aporte real']/montante
    elif mark == '':
        mark = f'{ativo["Ativo"]}-{restante_aporte}'
    i+=1

print('Prioridade')
wallet = sorted(wallet, key=itemgetter('Prioridade'))
i=0
while restante_aporte > preco_minimo:
    print('restante_aporte: ', restante_aporte)
    if i == len(wallet):
        i = 0
    ativo = wallet[i]
    print(ativo['Ativo'])
    print('Preço: ', ativo['Preço'])
    if ativo['Comprar']:
        if ativo['Ativo'] != 'Tesouro Selic' and restante_aporte > ativo['Preço']:
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 1
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']
        elif ativo['Ativo'] == 'Tesouro Selic' and restante_aporte > ativo['Preço']/100:
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            ativo['Quantidade Aporte'] += 0.01
            ativo['Aporte Real'] = ativo['Quantidade Aporte']*ativo['Preço']
            print(ativo['Quantidade Aporte'])
            print(ativo['Aporte Real'])
            restante_aporte -= ativo['Preço']/100
    i+=1
# Out:
# restante_aporte:  553.8822
# IVVB11
# 1.0
# 238.33
# 2.0
# 476.66
# restante_aporte:  315.55219999999997
# Tesouro Selic
# 0.03
# 411.45779999999996
# 0.04
# 548.6104
# restante_aporte:  178.39959999999996
# BTLG11
# 3.0
# 305.64
# 4.0
# 407.52
# restante_aporte:  76.51959999999997
# VGIP11
# restante_aporte:  76.51959999999997
# PVBI11
# restante_aporte:  76.51959999999997
# HGRU11
# restante_aporte:  76.51959999999997
# EGIE3
# 8.0
# 347.28
# 9.0
# 390.68999999999994
# restante_aporte:  33.10959999999997
# BBAS3
# restante_aporte:  33.10959999999997
# RBRP11
# restante_aporte:  33.10959999999997
# BLAU3
# 24.0
# 396.72
# 25.0
# 413.25
# restante_aporte:  16.57959999999997
# MALL11
# restante_aporte:  16.57959999999997
# B5P211
# restante_aporte:  16.57959999999997
# AGRO3
# restante_aporte:  16.57959999999997
# IVVB11
# restante_aporte:  16.57959999999997
# Tesouro Selic
# restante_aporte:  16.57959999999997
# BTLG11
# restante_aporte:  16.57959999999997
# VGIP11
# restante_aporte:  16.57959999999997
# PVBI11
# restante_aporte:  16.57959999999997
# HGRU11
# restante_aporte:  16.57959999999997
# EGIE3
# restante_aporte:  16.57959999999997
# BBAS3
# restante_aporte:  16.57959999999997
# RBRP11
# restante_aporte:  16.57959999999997
# BLAU3
# 25.0
# 413.25
# 26.0
# 429.78000000000003
# Prioridade

# %%
df = pd.DataFrame(wallet)
df['Posição após aporte real'] = df['Posição'] + df['Aporte Real']
df['Balanceamento após aporte real'] = df['Posição após aporte real']/df['Posição após aporte real'].sum()

# %%
print(atual+aporte)
print(df['Aporte Ideal'].sum())
print(df['Posição Ideal'].sum())
print(df['Aporte Real'].sum())
print(restante_aporte)
df.sort_values('Prioridade')
# Out:
# 7900.0452
# 5400.0
# 7900.0452000000005
# 5399.9504
# 0.04959999999996967
#             Ativo  Prioridade  Quantidade Atual  Balanceamento  Comprar  \
# 0          BTLG11           1              2.00          0.075     True
# 1           BBAS3           2              4.00          0.075     True
# 2           BLAU3           3             11.00          0.075     True
# 3           EGIE3           4              5.00          0.075     True
# 4          VGIP11           5              2.00          0.075     True
# 5          MALL11           6              2.00          0.075     True
# 6          PVBI11           7              1.00          0.075     True
# 7           AGRO3           8              7.00          0.075     True
# 8          HGRU11           9              1.00          0.075     True
# 9          IVVB11          10              1.00          0.075     True
# 10         B5P211          11              2.00          0.075     True
# 11         RBRP11          12              3.00          0.075     True
# 12  Tesouro Selic          13              0.02          0.100     True
#
#        Preço   Posição  Balanceamento Atual  Posição Ideal  Aporte Ideal  \
# 0     101.88  203.7600             0.081503      592.50339     388.74339
# 1      47.70  190.8000             0.076319      592.50339     401.70339
# 2      16.53  181.8300             0.072731      592.50339     410.67339
# 3      43.41  217.0500             0.086818      592.50339     375.45339
# 4      89.22  178.4400             0.071375      592.50339     414.06339
# 5     116.55  233.1000             0.093238      592.50339     359.40339
# 6     107.20  107.2000             0.042879      592.50339     485.30339
# 7      28.14  196.9800             0.078791      592.50339     395.52339
# 8     137.85  137.8500             0.055139      592.50339     454.65339
# 9     238.33  238.3300             0.095330      592.50339     354.17339
# 10     83.95  167.9000             0.067159      592.50339     424.60339
# 11     57.50  172.5000             0.068999      592.50339     420.00339
# 12  13715.26  274.3052             0.109720      790.00452     515.69932
#
#     Quantidade Aporte  Aporte Real  Posição após aporte real  \
# 0                4.00     407.5200                  611.2800
# 1                8.00     381.6000                  572.4000
# 2               26.00     429.7800                  611.6100
# 3                9.00     390.6900                  607.7400
# 4                4.00     356.8800                  535.3200
# 5                3.00     349.6500                  582.7500
# 6                4.00     428.8000                  536.0000
# 7               14.00     393.9600                  590.9400
# 8                3.00     413.5500                  551.4000
# 9                2.00     476.6600                  714.9900
# 10               5.00     419.7500                  587.6500
# 11               7.00     402.5000                  575.0000
# 12               0.04     548.6104                  822.9156
#
#     Balanceamento após aporte real  Diferença Balanceamento
# 0                         0.077377                -0.005658
# 1                         0.072456                 0.002918
# 2                         0.077419                 0.003755
# 3                         0.076929                 0.001820
# 4                         0.067762                -0.002129
# 5                         0.073766                 0.004327
# 6                         0.067848                -0.002037
# 7                         0.074803                 0.005442
# 8                         0.069798                 0.000060
# 9                         0.090505                -0.010114
# 10                        0.074386                 0.004994
# 11                        0.072785                 0.003272
# 12                        0.104167                -0.006650

# %%
df['Quantidade Atual'] = df['Quantidade Atual'] + df['Quantidade Aporte']

# %%
df.sort_values('Prioridade')
# Out:
#             Ativo  Prioridade  Quantidade Atual  Balanceamento  Comprar  \
# 0          BTLG11           1              6.00          0.075     True
# 1           BBAS3           2             12.00          0.075     True
# 2           BLAU3           3             37.00          0.075     True
# 3           EGIE3           4             14.00          0.075     True
# 4          VGIP11           5              6.00          0.075     True
# 5          MALL11           6              5.00          0.075     True
# 6          PVBI11           7              5.00          0.075     True
# 7           AGRO3           8             21.00          0.075     True
# 8          HGRU11           9              4.00          0.075     True
# 9          IVVB11          10              3.00          0.075     True
# 10         B5P211          11              7.00          0.075     True
# 11         RBRP11          12             10.00          0.075     True
# 12  Tesouro Selic          13              0.06          0.100     True
#
#        Preço   Posição  Balanceamento Atual  Posição Ideal  Aporte Ideal  \
# 0     101.88  203.7600             0.081503      592.50339     388.74339
# 1      47.70  190.8000             0.076319      592.50339     401.70339
# 2      16.53  181.8300             0.072731      592.50339     410.67339
# 3      43.41  217.0500             0.086818      592.50339     375.45339
# 4      89.22  178.4400             0.071375      592.50339     414.06339
# 5     116.55  233.1000             0.093238      592.50339     359.40339
# 6     107.20  107.2000             0.042879      592.50339     485.30339
# 7      28.14  196.9800             0.078791      592.50339     395.52339
# 8     137.85  137.8500             0.055139      592.50339     454.65339
# 9     238.33  238.3300             0.095330      592.50339     354.17339
# 10     83.95  167.9000             0.067159      592.50339     424.60339
# 11     57.50  172.5000             0.068999      592.50339     420.00339
# 12  13715.26  274.3052             0.109720      790.00452     515.69932
#
#     Quantidade Aporte  Aporte Real  Posição após aporte real  \
# 0                4.00     407.5200                  611.2800
# 1                8.00     381.6000                  572.4000
# 2               26.00     429.7800                  611.6100
# 3                9.00     390.6900                  607.7400
# 4                4.00     356.8800                  535.3200
# 5                3.00     349.6500                  582.7500
# 6                4.00     428.8000                  536.0000
# 7               14.00     393.9600                  590.9400
# 8                3.00     413.5500                  551.4000
# 9                2.00     476.6600                  714.9900
# 10               5.00     419.7500                  587.6500
# 11               7.00     402.5000                  575.0000
# 12               0.04     548.6104                  822.9156
#
#     Balanceamento após aporte real  Diferença Balanceamento
# 0                         0.077377                -0.005658
# 1                         0.072456                 0.002918
# 2                         0.077419                 0.003755
# 3                         0.076929                 0.001820
# 4                         0.067762                -0.002129
# 5                         0.073766                 0.004327
# 6                         0.067848                -0.002037
# 7                         0.074803                 0.005442
# 8                         0.069798                 0.000060
# 9                         0.090505                -0.010114
# 10                        0.074386                 0.004994
# 11                        0.072785                 0.003272
# 12                        0.104167                -0.006650
